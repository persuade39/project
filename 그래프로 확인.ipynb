# %%
#선언
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'

matplotlib.rcParams['axes.unicode_minus'] =False

# %%
#데이터셋 불러오기
train_df = pd.read_csv('C:/Users/w7e7r/Desktop/스파르타/심화프로젝트/train.csv')
train_df.head()
train_df.tail()
# Out:
#                 ID      대출금액        대출기간       근로기간    주택소유상태       연간소득  \
# 96289  TRAIN_96289  14400000   36 months  10+ years  MORTGAGE  210000000
# 96290  TRAIN_96290  28800000   60 months  10+ years  MORTGAGE  132000000
# 96291  TRAIN_96291  14400000   36 months     1 year  MORTGAGE   84000000
# 96292  TRAIN_96292  15600000   36 months    5 years  MORTGAGE   66330000
# 96293  TRAIN_96293   8640000   36 months  10+ years      RENT   50400000
#
#        부채_대비_소득_비율  총계좌수   대출목적  최근_2년간_연체_횟수    총상환원금     총상환이자  총연체금액  \
# 96289         9.33    33  신용 카드             0   974580  492168.0    0.0
# 96290         5.16    25  주택 개선             0   583728  855084.0    0.0
# 96291        11.24    22  신용 카드             0  1489128  241236.0    0.0
# 96292        17.30    21  부채 통합             2  1378368  818076.0    0.0
# 96293        11.80    14  신용 카드             0   596148  274956.0    0.0
#
#        연체계좌수 대출등급
# 96289    0.0    C
# 96290    0.0    E
# 96291    0.0    A
# ...

# %% [markdown]
# # 대출등급 그래프로 확인

# %%
sns.countplot(data = train_df, x = '대출등급')
# Out:
# <Axes: xlabel='대출등급', ylabel='count'>

# %% [markdown]
# # boxplot

# %%
sns.boxplot(data = train_df, x = '대출금액',y = '대출등급')
# Out:
# <Axes: xlabel='대출금액', ylabel='대출등급'>

# %%
sns.boxplot(data = train_df, x = '대출기간',y = '대출등급')
# Out:
# <Axes: xlabel='대출기간', ylabel='대출등급'>

# %% [markdown]
# - 대출기간 36개월에 이상치

# %%
sns.boxplot(data = train_df, x = '주택소유상태',y = '대출등급')
# Out:
# <Axes: xlabel='주택소유상태', ylabel='대출등급'>

# %% [markdown]
# - 주택소유상태에서 이상치, any(any가 결측치인가?)

# %%
plt.figure(figsize=(13,13))
sns.boxplot(data=train_df, x='근로기간', y='대출등급')
plt.show()

# %% [markdown]
# - 10+ years = 10+years 해야함
# - 3 = 3 years
# - 1 years= 1 year
# - unknown은 어떡하지

# %%
sns.boxplot(data = train_df, x = '총계좌수',y = '대출등급')
# Out:
# <Axes: xlabel='총계좌수', ylabel='대출등급'>

# %% [markdown]
# - 이상치 많음

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=train_df, x='대출목적', y='대출등급')
plt.show()

# %% [markdown]
# - A~G하고 싶은데

# %%
sns.boxplot(data = train_df, x = '총상환이자',y = '대출등급')
# Out:
# <Axes: xlabel='총상환이자', ylabel='대출등급'>

# %% [markdown]
# - 이상치 많음

# %% [markdown]
# # 히스토그램

# %%
sns.histplot(data = train_df, x = '대출등급')
# Out:
# <Axes: xlabel='대출등급', ylabel='Count'>

# %% [markdown]
# - B등급에 제일 많음
# - 순서대로 어떻게 하지?

# %%
sns.histplot(data = train_df, x = '대출기간')
# Out:
# <Axes: xlabel='대출기간', ylabel='Count'>

# %% [markdown]
# - 36개월 대출 기간이 제일 많음 -> 왜?

# %%
sns.histplot(data = train_df, x = '주택소유상태')
# Out:
# <Axes: xlabel='주택소유상태', ylabel='Count'>

# %% [markdown]
# - 전세가 많음
# - any가 뭐지

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data = train_df, x = '대출목적')
plt.show()

# %% [markdown]
# # pariplot

# %%
sns.pairplot(data = train_df)

# %% [markdown]
# - 으악.
