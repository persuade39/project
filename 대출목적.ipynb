# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
plt.rcParams['font.family'] = 'AppleGothic'
# Out:
# /var/folders/p6/zn1thsjj39x22wz5h1vhtxlh0000gn/T/ipykernel_35568/877141220.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv('/Users/jeong-yula/Downloads/open/train.csv')

# %%
def year_encoder(x):
    output = x.replace('years', '')
    output = output.replace('year', '')
    output = output.replace('+', '')
    output = output.replace('<', '')
    output = output.replace('Unknown', '-1').strip()
    output = int(output)

    return output

df['근로기간'] = df['근로기간'].apply(year_encoder)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='대출목적',y='대출금액',data=df)
# Out:
# <Axes: xlabel='대출목적', ylabel='대출금액'>

# %% [markdown]
# 부채통합/신옹카드 ~ 높은 대출금액

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='대출목적',y='연간소득',data=df)
# Out:
# <Axes: xlabel='대출목적', ylabel='연간소득'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='대출목적',y='부채_대비_소득_비율',data=df)
# Out:
# <Axes: xlabel='대출목적', ylabel='부채_대비_소득_비율'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='대출목적',y='총계좌수',data=df)
# Out:
# <Axes: xlabel='대출목적', ylabel='총계좌수'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='대출목적',y='최근_2년간_연체_횟수',data=df)
# Out:
# <Axes: xlabel='대출목적', ylabel='최근_2년간_연체_횟수'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='대출목적',y='총상환원금',data=df)
# Out:
# <Axes: xlabel='대출목적', ylabel='총상환원금'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='대출목적',y='총상환이자',data=df)
# Out:
# <Axes: xlabel='대출목적', ylabel='총상환이자'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='대출목적',y='총연체금액',data=df)
# Out:
# <Axes: xlabel='대출목적', ylabel='총연체금액'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='대출목적',y='연체계좌수',data=df)
# Out:
# <Axes: xlabel='대출목적', ylabel='연체계좌수'>
