# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
plt.rcParams['font.family'] = 'AppleGothic'
# Out:
# /var/folders/p6/zn1thsjj39x22wz5h1vhtxlh0000gn/T/ipykernel_35372/877141220.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv('/Users/jeong-yula/Downloads/open/train.csv')

# %%
drop_index = df[df['주택소유상태'] == 'ANY'].index
df = df.drop(drop_index)

# %%
def year_encoder(x):
    output = x.replace('years', '')
    output = output.replace('year', '')
    output = output.replace('+', '')
    output = output.replace('<', '')
    output = output.replace('Unknown', '-1').strip()
    output = int(output)

    return output

df['근로기간'] = df['근로기간'].apply(year_encoder)

# %%
sns.barplot(x='주택소유상태',y='대출금액',data=df)
# Out:
# <Axes: xlabel='주택소유상태', ylabel='대출금액'>

# %%
sns.barplot(x='주택소유상태',y='대출금액',data=df, hue='대출기간')
# Out:
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='주택소유상태', ylabel='대출금액'>

# %%
sns.barplot(x='주택소유상태',y='연간소득',data=df)
# Out:
# <Axes: xlabel='주택소유상태', ylabel='연간소득'>

# %%
sns.barplot(x='주택소유상태',y='연간소득',data=df, hue='근로기간' )
# Out:
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.barplot(x='주택소유상태',y='부채_대비_소득_비율',data=df)
# Out:
# <Axes: xlabel='주택소유상태', ylabel='부채_대비_소득_비율'>

# %%
sns.barplot(x='주택소유상태',y='부채_대비_소득_비율',data=df, hue='대출기간')
# Out:
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='주택소유상태', ylabel='부채_대비_소득_비율'>

# %%
sns.barplot(x='주택소유상태',y='총계좌수',data=df)
# Out:
# <Axes: xlabel='주택소유상태', ylabel='총계좌수'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='주택소유상태',y='총계좌수',data=df, hue='대출목적')
# Out:
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.barplot(x='주택소유상태',y='최근_2년간_연체_횟수',data=df)
# Out:
# <Axes: xlabel='주택소유상태', ylabel='최근_2년간_연체_횟수'>

# %%
sns.barplot(x='주택소유상태',y='최근_2년간_연체_횟수',data=df,hue='근로기간')
# Out:
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.barplot(x='주택소유상태',y='총상환원금',data=df)
# Out:
# <Axes: xlabel='주택소유상태', ylabel='총상환원금'>

# %%
sns.barplot(x='주택소유상태',y='총상환원금',data=df,hue='근로기간')
# Out:
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.barplot(x='주택소유상태',y='총상환이자',data=df)
# Out:
# <Axes: xlabel='주택소유상태', ylabel='총상환이자'>

# %%
sns.barplot(x='주택소유상태',y='총연체금액',data=df)
# Out:
# <Axes: xlabel='주택소유상태', ylabel='총연체금액'>

# %%
sns.barplot(x='주택소유상태',y='총연체금액',data=df,hue='근로기간')
# Out:
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jeong-yula/Library/Python/3.9/lib/python/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# 자가. 근로기간8,10. 연체금액

# %%
df['주택소유상태'].unique()
# Out:
# array(['RENT', 'MORTGAGE', 'OWN'], dtype=object)

# %%
df['근로기간'].unique()
# Out:
# array([ 6, 10,  5,  8, -1,  9,  2,  1,  3,  7,  4])

# %%
is_own=df['주택소유상태']=='OWN'
over_8years=df['근로기간']>=8
subset_df=df[is_own&over_8years]
subset_df['총연체금액'].value_counts()
# Out:
# 총연체금액
# 0.0        4496
# 18000.0       4
# 35304.0       1
# 19212.0       1
# 52884.0       1
# 28884.0       1
# 48300.0       1
# 43968.0       1
# 52452.0       1
# 23592.0       1
# Name: count, dtype: int64

# %%
sns.barplot(x='주택소유상태',y='연체계좌수',data=df)
# Out:
# <Axes: xlabel='주택소유상태', ylabel='연체계좌수'>
