# %%
#선언
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#데이터셋 불러오기
train_df = pd.read_csv('C:/Users/w7e7r/Desktop/스파르타/심화프로젝트/train.csv')
train_df.head()
train_df.tail()
# Out:
#                 ID      대출금액        대출기간       근로기간    주택소유상태       연간소득  \
# 96289  TRAIN_96289  14400000   36 months  10+ years  MORTGAGE  210000000
# 96290  TRAIN_96290  28800000   60 months  10+ years  MORTGAGE  132000000
# 96291  TRAIN_96291  14400000   36 months     1 year  MORTGAGE   84000000
# 96292  TRAIN_96292  15600000   36 months    5 years  MORTGAGE   66330000
# 96293  TRAIN_96293   8640000   36 months  10+ years      RENT   50400000
#
#        부채_대비_소득_비율  총계좌수   대출목적  최근_2년간_연체_횟수    총상환원금     총상환이자  총연체금액  \
# 96289         9.33    33  신용 카드             0   974580  492168.0    0.0
# 96290         5.16    25  주택 개선             0   583728  855084.0    0.0
# 96291        11.24    22  신용 카드             0  1489128  241236.0    0.0
# 96292        17.30    21  부채 통합             2  1378368  818076.0    0.0
# 96293        11.80    14  신용 카드             0   596148  274956.0    0.0
#
#        연체계좌수 대출등급
# 96289    0.0    C
# 96290    0.0    E
# 96291    0.0    A
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96294 entries, 0 to 96293
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            96294 non-null  object
#  1   대출금액          96294 non-null  int64
#  2   대출기간          96294 non-null  object
#  3   근로기간          96294 non-null  object
#  4   주택소유상태        96294 non-null  object
#  5   연간소득          96294 non-null  int64
#  6   부채_대비_소득_비율   96294 non-null  float64
#  7   총계좌수          96294 non-null  int64
#  8   대출목적          96294 non-null  object
#  9   최근_2년간_연체_횟수  96294 non-null  int64
#  10  총상환원금         96294 non-null  int64
#  11  총상환이자         96294 non-null  float64
#  12  총연체금액         96294 non-null  float64
#  13  연체계좌수         96294 non-null  float64
#  14  대출등급          96294 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 11.0+ MB

# %% [markdown]
# # 근로기간

# %%
train_df[train_df['근로기간'].isin(['10+ years','10+years'])]
# Out:
#                 ID      대출금액        대출기간       근로기간    주택소유상태       연간소득  \
# 1      TRAIN_00001  14400000   60 months  10+ years  MORTGAGE  130800000
# 5      TRAIN_00005   4800000   36 months  10+ years      RENT   84000000
# 8      TRAIN_00008   9840000   36 months  10+ years       OWN   45600000
# 13     TRAIN_00013  12000000   36 months  10+ years  MORTGAGE   48000000
# 16     TRAIN_00016  42000000   60 months  10+ years  MORTGAGE  134400000
# ...            ...       ...         ...        ...       ...        ...
# 96280  TRAIN_96280  42000000   60 months  10+ years  MORTGAGE   85200000
# 96287  TRAIN_96287  12000000   36 months  10+ years  MORTGAGE  132000000
# 96289  TRAIN_96289  14400000   36 months  10+ years  MORTGAGE  210000000
# 96290  TRAIN_96290  28800000   60 months  10+ years  MORTGAGE  132000000
# 96293  TRAIN_96293   8640000   36 months  10+ years      RENT   50400000
#
#        부채_대비_소득_비율  총계좌수   대출목적  최근_2년간_연체_횟수    총상환원금      총상환이자  총연체금액  \
# ...

# %%
train_df['근로기간'] = train_df['근로기간'].replace('10+years', '10+ years')

# 변경된 데이터 확인
print(train_df['근로기간'].unique())
# Out:
# ['6 years' '10+ years' '5 years' '8 years' 'Unknown' '9 years' '2 years'
#  '1 year' '3 years' '7 years' '4 years' '< 1 year' '<1 year' '3' '1 years']

# %%
train_df[train_df['근로기간'].isin(['1 years','1 year'])]
# Out:
#                 ID      대출금액        대출기간    근로기간    주택소유상태       연간소득  \
# 10     TRAIN_00010  19980000   60 months  1 year      RENT   60000000
# 25     TRAIN_00025  24000000   36 months  1 year  MORTGAGE  140400000
# 29     TRAIN_00029  24840000   60 months  1 year      RENT   99600000
# 39     TRAIN_00039  30000000   60 months  1 year  MORTGAGE   90000000
# 51     TRAIN_00051  14400000   36 months  1 year  MORTGAGE  108000000
# ...            ...       ...         ...     ...       ...        ...
# 96225  TRAIN_96225  19200000   60 months  1 year      RENT  141600000
# 96272  TRAIN_96272  22170000   36 months  1 year  MORTGAGE   96000000
# 96282  TRAIN_96282  28800000   60 months  1 year      RENT  126000000
# 96283  TRAIN_96283   9600000   36 months  1 year  MORTGAGE   48000000
# 96291  TRAIN_96291  14400000   36 months  1 year  MORTGAGE   84000000
#
#        부채_대비_소득_비율  총계좌수    대출목적  최근_2년간_연체_횟수    총상환원금      총상환이자  총연체금액  \
# ...

# %%
train_df['근로기간'] = train_df['근로기간'].replace('1 years','1 year')

# 변경된 데이터 확인
print(train_df['근로기간'].unique())
# Out:
# ['6 years' '10+ years' '5 years' '8 years' 'Unknown' '9 years' '2 years'
#  '1 year' '3 years' '7 years' '4 years' '< 1 year' '<1 year' '3']

# %%
train_df[train_df['근로기간'].isin(['3 years','3'])]
# Out:
#                 ID      대출금액        대출기간     근로기간    주택소유상태       연간소득  \
# 11     TRAIN_00011  14400000   60 months  3 years      RENT   66000000
# 35     TRAIN_00035  33600000   36 months  3 years  MORTGAGE  168000000
# 41     TRAIN_00041   4800000   36 months  3 years      RENT   18000000
# 42     TRAIN_00042  42000000   60 months  3 years  MORTGAGE   92400000
# 45     TRAIN_00045  19200000   36 months  3 years  MORTGAGE   66000000
# ...            ...       ...         ...      ...       ...        ...
# 96247  TRAIN_96247   7200000   36 months  3 years       OWN   42000000
# 96252  TRAIN_96252   2580000   36 months  3 years       OWN   79200000
# 96254  TRAIN_96254  17940000   60 months  3 years      RENT   52800000
# 96265  TRAIN_96265  16800000   60 months  3 years  MORTGAGE   78000000
# 96270  TRAIN_96270  21120000   36 months  3 years       OWN   48000000
#
#        부채_대비_소득_비율  총계좌수    대출목적  최근_2년간_연체_횟수    총상환원금     총상환이자  총연체금액  \
# ...

# %%
train_df['근로기간'] = train_df['근로기간'].replace('3','3 years')

# 변경된 데이터 확인
print(train_df['근로기간'].unique())
# Out:
# ['6 years' '10+ years' '5 years' '8 years' 'Unknown' '9 years' '2 years'
#  '1 year' '3 years' '7 years' '4 years' '< 1 year' '<1 year']

# %%
train_df[train_df['근로기간'].isin(['< 1 year' '<1 year'])]
# Out:
# Empty DataFrame
# Columns: [ID, 대출금액, 대출기간, 근로기간, 주택소유상태, 연간소득, 부채_대비_소득_비율, 총계좌수, 대출목적, 최근_2년간_연체_횟수, 총상환원금, 총상환이자, 총연체금액, 연체계좌수, 대출등급]
# Index: []

# %% [markdown]
# - 삭제해야하나?

# %%
train_df.head()
# Out:
#             ID      대출금액        대출기간       근로기간    주택소유상태       연간소득  \
# 0  TRAIN_00000  12480000   36 months    6 years      RENT   72000000
# 1  TRAIN_00001  14400000   60 months  10+ years  MORTGAGE  130800000
# 2  TRAIN_00002  12000000   36 months    5 years  MORTGAGE   96000000
# 3  TRAIN_00003  14400000   36 months    8 years  MORTGAGE  132000000
# 4  TRAIN_00004  18000000   60 months    Unknown      RENT   71736000
#
#    부채_대비_소득_비율  총계좌수   대출목적  최근_2년간_연체_횟수   총상환원금     총상환이자  총연체금액  연체계좌수 대출등급
# 0        18.90    15  부채 통합             0       0       0.0    0.0    0.0    C
# 1        22.33    21  주택 개선             0  373572  234060.0    0.0    0.0    B
# 2         8.60    14  부채 통합             0  928644  151944.0    0.0    0.0    A
# 3        15.09    15  부채 통합             0  325824  153108.0    0.0    0.0    C
# 4        25.39    19  주요 구매             0  228540  148956.0    0.0    0.0    B

# %% [markdown]
# # 목적

# %%
print(train_df['대출목적'].unique())
# Out:
# ['부채 통합' '주택 개선' '주요 구매' '휴가' '의료' '자동차' '신용 카드' '소규모 사업' '기타' '이사' '주택'
#  '재생 에너지']

# %%
train_df['대출목적'] = train_df['대출목적'].replace(['주택 개선', '이사', '주택'], '주택 관련')

# 변경된 데이터 확인
print(train_df['대출목적'].unique())
# Out:
# ['부채 통합' '주택 관련' '주요 구매' '휴가' '의료' '자동차' '신용 카드' '소규모 사업' '기타' '재생 에너지']

# %%
train_df.head()
# Out:
#             ID      대출금액        대출기간       근로기간    주택소유상태       연간소득  \
# 0  TRAIN_00000  12480000   36 months    6 years      RENT   72000000
# 1  TRAIN_00001  14400000   60 months  10+ years  MORTGAGE  130800000
# 2  TRAIN_00002  12000000   36 months    5 years  MORTGAGE   96000000
# 3  TRAIN_00003  14400000   36 months    8 years  MORTGAGE  132000000
# 4  TRAIN_00004  18000000   60 months    Unknown      RENT   71736000
#
#    부채_대비_소득_비율  총계좌수   대출목적  최근_2년간_연체_횟수   총상환원금     총상환이자  총연체금액  연체계좌수 대출등급
# 0        18.90    15  부채 통합             0       0       0.0    0.0    0.0    C
# 1        22.33    21  주택 관련             0  373572  234060.0    0.0    0.0    B
# 2         8.60    14  부채 통합             0  928644  151944.0    0.0    0.0    A
# 3        15.09    15  부채 통합             0  325824  153108.0    0.0    0.0    C
# 4        25.39    19  주요 구매             0  228540  148956.0    0.0    0.0    B

# %%
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'

matplotlib.rcParams['axes.unicode_minus'] =False

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=train_df, x='대출목적', y='대출등급')
plt.show()

# %% [markdown]
# - 저장하려면 이름을 바꿔야 하나?\
#  -> 어떻게 바꾸지

# %% [markdown]
# - unknown 처리,,\
#  -> 1 years 10+ years 이래서 흠,,
